# %% [markdown]
# # Visualizing Data with ggplot2
# ## Overview
# Earlier in this course, you encountered ggplot2, an R package for data visualization . In this activity, you'll learn about the basic logic of data visualization in ggplot2 and how to create a plot using R code . By the time you complete this activity , you'll be able to write R functions that create data visualizations . This will enable you to create basic visualizations to demonstrate and share findings with your data and code.

# %% [markdown]
# ### Prepare Data

# %% [markdown]
# #### Load Packages

# %%
install.packages("ggplot2")
install.packages("palmerpenguins")
library(ggplot2)
library(palmerpenguins)

# %% [markdown]
# #### Examine the Data

# %%
data(penguins)
View(penguins)

# %% [markdown]
# ### Create a Plot using ggplot2

# %%
ggplot(data = penguins) + geom_point(mapping = aes(x = flipper_length_mm, y = body_mass_g))

# %% [markdown]
# ![image.png](attachment:8d50a0c2-b626-463b-a5f3-c6a844609fbb.png)

# %%
ggplot(data = penguins) + geom_point(mapping = aes(x = bill_length_mm, y = flipper_length_mm))

# %% [markdown]
# ![image.png](attachment:646afaa6-c71c-4e6b-87bb-1de8794f7f6b.png)

# %%
ggplot(data = penguins) + geom_point(mapping = aes(x = flipper_length_mm, y = body_mass_g, color = species))

# %% [markdown]
# ![image.png](attachment:8a597cdf-d227-4a2f-9b45-fda75fc9027e.png)

# %%
ggplot(data = penguins) + geom_point(mapping = aes(x = bill_length_mm, y = flipper_length_mm, color = species))

# %% [markdown]
# ![image.png](attachment:a5b94600-b53d-4682-bf26-f0ea2819ad7d.png)
